# %%
02_model_experiments.ipynb

1. Load + merge all 5 projects
2. Define target
3. Define feature sets
   ├── CK
   ├── Change
   └── CK + Change
4. LOPO evaluation
5. Logistic Regression baseline
6. Random Forest
7. Extra Trees
8. Gradient boosting
9. Compare models
10. Feature importance
11. Probability calibration
12. Select final model
