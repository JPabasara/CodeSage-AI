# %%
from pathlib import Path

import pandas as pd

# %%
DATA_ROOT = Path("../data/raw")

PROJECTS = [
    "eclipse",
    "equinox",
    "lucene",
    "mylyn",
    "pde",
]

# %%
def load_project(project_name):
    data_dir = DATA_ROOT / project_name

    ck = pd.read_csv(
        data_dir / "single-version-ck-oo.csv",
        sep=";",
    )

    change = pd.read_csv(
        data_dir / "change-metrics.csv",
        sep=";",
    )

    ck = clean_columns(ck)
    change = clean_columns(change)

    # Each class should occur exactly once.
    assert not ck["classname"].duplicated().any()
    assert not change["classname"].duplicated().any()

    # CK and change datasets should describe the same classes.
    assert set(ck["classname"]) == set(change["classname"])

    # Verify that the bug labels agree between the two datasets.
    label_check = ck[["classname", "bugs"]].merge(
        change[["classname", "bugs"]],
        on="classname",
        suffixes=("_ck", "_change"),
        validate="one_to_one",
    )

    assert (
        label_check["bugs_ck"] ==
        label_check["bugs_change"]
    ).all()

    # Keep the bug labels from CK and remove duplicate labels
    # from the change-metrics dataset.
    change_features = change.drop(
        columns=[
            "bugs",
            "nonTrivialBugs",
            "majorBugs",
            "criticalBugs",
            "highPriorityBugs",
        ]
    )

    merged = ck.merge(
        change_features,
        on="classname",
        how="inner",
        validate="one_to_one",
    )

    # Needed for leave-one-project-out evaluation later.
    merged["project"] = project_name

    # Binary prediction target.
    merged["defective"] = (
        merged["bugs"] > 0
    ).astype(int)

    return merged

# %%
def clean_columns(df):
    df = df.copy()
    df.columns = (
        df.columns
        .str.strip()
        .str.rstrip(":")
        .str.strip()
    )
    return df

# %%
project_dfs = [
    load_project(project)
    for project in PROJECTS
]

all_df = pd.concat(
    project_dfs,
    ignore_index=True,
)

# %%
all_df.groupby("project")["defective"].agg(
    observations="size",
    defective="sum",
    defect_rate="mean",
)
# Out:
#          observations  defective  defect_rate
# project
# eclipse           997        206     0.206620
# equinox           324        129     0.398148
# lucene            691         64     0.092619
# mylyn            1862        245     0.131579
# pde              1497        209     0.139613

# %%
CK_FEATURES = [
    "wmc",
    "cbo",
    "dit",
    "lcom",
    "rfc",
    "noc",
    "numberOfLinesOfCode",
    "numberOfMethods",
]

CHANGE_FEATURES = [
    "numberOfVersionsUntil",
    "numberOfAuthorsUntil",
    "linesAddedUntil",
    "maxLinesAddedUntil",
    "avgLinesAddedUntil",
    "linesRemovedUntil",
    "maxLinesRemovedUntil",
    "avgLinesRemovedUntil",
    "codeChurnUntil",
    "maxCodeChurnUntil",
    "avgCodeChurnUntil",
    "ageWithRespectTo",
    "weightedAgeWithRespectTo",
]

FEATURES = CK_FEATURES + CHANGE_FEATURES

print("Number of features:", len(FEATURES))
# Out:
# Number of features: 21

# %%
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    average_precision_score,
    brier_score_loss,
    roc_auc_score,
)
from sklearn.model_selection import ParameterGrid

# %%
PARAM_GRID = {
    "n_estimators": [200],
    "max_depth": [None, 10, 20],
    "min_samples_leaf": [1, 3, 5],
    "max_features": ["sqrt", 0.5],
    "class_weight": ["balanced", "balanced_subsample"],
}

# %%
param_combinations = list(ParameterGrid(PARAM_GRID))

print(
    "Parameter combinations:",
    len(param_combinations),
)
# Out:
# Parameter combinations: 36

# %%
def make_random_forest(params):
    return RandomForestClassifier(
        **params,
        random_state=42,
        n_jobs=-1,
    )

# %%
def evaluate_inner_lopo(
    training_df,
    features,
    params,
):
    scores = []

    inner_projects = sorted(
        training_df["project"].unique()
    )

    for validation_project in inner_projects:
        inner_train = training_df[
            training_df["project"] != validation_project
        ]

        inner_validation = training_df[
            training_df["project"] == validation_project
        ]

        X_train = inner_train[features]
        y_train = inner_train["defective"]

        X_validation = inner_validation[features]
        y_validation = inner_validation["defective"]

        model = make_random_forest(params)

        model.fit(
            X_train,
            y_train,
        )

        probabilities = model.predict_proba(
            X_validation
        )[:, 1]

        pr_auc = average_precision_score(
            y_validation,
            probabilities,
        )

        scores.append(pr_auc)

    return np.mean(scores)

# %%
def select_best_parameters(
    training_df,
    features,
    param_grid,
):
    combinations = list(ParameterGrid(param_grid))

    results = []
    best_params = None
    best_score = -np.inf

    for i, params in enumerate(combinations, start=1):
        print(
            f"    [{i}/{len(combinations)}] {params}",
            flush=True,
        )

        mean_pr_auc = evaluate_inner_lopo(
            training_df,
            features,
            params,
        )

        results.append({
            **params,
            "mean_pr_auc": mean_pr_auc,
        })

        if mean_pr_auc > best_score:
            best_score = mean_pr_auc
            best_params = params.copy()

    results_df = pd.DataFrame(results)

    return best_params, results_df

# %%
def nested_lopo(
    df,
    features,
    param_grid,
):
    outer_results = []
    tuning_results = {}

    outer_projects = sorted(
        df["project"].unique()
    )

    for outer_i, test_project in enumerate(
        outer_projects,
        start=1,
    ):
        print()
        print("=" * 60)
        print(
            f"OUTER [{outer_i}/{len(outer_projects)}] "
            f"Held-out project: {test_project}"
        )
        print("=" * 60)

        outer_train = df[
            df["project"] != test_project
        ]

        outer_test = df[
            df["project"] == test_project
        ]

        print("Selecting hyperparameters...")

        best_params, search_results = (
            select_best_parameters(
                outer_train,
                features,
                param_grid,
            )
        )

        tuning_results[test_project] = search_results

        print()
        print("Best parameters:")
        print(best_params)

        # Retrain using ALL four available training projects.
        model = make_random_forest(best_params)

        model.fit(
            outer_train[features],
            outer_train["defective"],
        )

        # Only now touch the outer test project.
        probabilities = model.predict_proba(
            outer_test[features]
        )[:, 1]

        y_test = outer_test["defective"]

        result = {
            "test_project": test_project,
            "n_train": len(outer_train),
            "n_test": len(outer_test),
            "defect_rate": y_test.mean(),

            "roc_auc": roc_auc_score(
                y_test,
                probabilities,
            ),

            "pr_auc": average_precision_score(
                y_test,
                probabilities,
            ),

            "brier": brier_score_loss(
                y_test,
                probabilities,
            ),

            **{
                f"best_{key}": value
                for key, value in best_params.items()
            },
        }

        outer_results.append(result)

        print()
        print(
            f"OUTER RESULT: "
            f"ROC={result['roc_auc']:.4f}, "
            f"PR={result['pr_auc']:.4f}, "
            f"Brier={result['brier']:.4f}"
        )

    return (
        pd.DataFrame(outer_results),
        tuning_results,
    )

# %%
nested_results, tuning_results = nested_lopo(
    all_df,
    FEATURES,
    PARAM_GRID,
)
# Out:
# ============================================================
# OUTER [1/5] Held-out project: eclipse
# ============================================================
# Selecting hyperparameters...
#     [1/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [2/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [3/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [4/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [5/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [6/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [7/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [8/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [9/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [10/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [11/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [12/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [13/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [14/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [15/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [16/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [17/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [18/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [19/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [20/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [21/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [22/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [23/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [24/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [25/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [26/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [27/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [28/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [29/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [30/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [31/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [32/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [33/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [34/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [35/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [36/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#
# Best parameters:
# {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#
# OUTER RESULT: ROC=0.7456, PR=0.5250, Brier=0.2728
#
# ============================================================
# OUTER [2/5] Held-out project: equinox
# ============================================================
# Selecting hyperparameters...
#     [1/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [2/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [3/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [4/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [5/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [6/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [7/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [8/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [9/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [10/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [11/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [12/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [13/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [14/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [15/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [16/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [17/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [18/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [19/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [20/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [21/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [22/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [23/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [24/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [25/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [26/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [27/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [28/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [29/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [30/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [31/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [32/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [33/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [34/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [35/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [36/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#
# Best parameters:
# {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#
# OUTER RESULT: ROC=0.7486, PR=0.6943, Brier=0.1968
#
# ============================================================
# OUTER [3/5] Held-out project: lucene
# ============================================================
# Selecting hyperparameters...
#     [1/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [2/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [3/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [4/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [5/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [6/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [7/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [8/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [9/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [10/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [11/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [12/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [13/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [14/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [15/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [16/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [17/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [18/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [19/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [20/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [21/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [22/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [23/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [24/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [25/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [26/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [27/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [28/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [29/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [30/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [31/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [32/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [33/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [34/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [35/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [36/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#
# Best parameters:
# {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#
# OUTER RESULT: ROC=0.7291, PR=0.3373, Brier=0.1156
#
# ============================================================
# OUTER [4/5] Held-out project: mylyn
# ============================================================
# Selecting hyperparameters...
#     [1/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [2/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [3/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [4/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [5/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [6/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [7/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [8/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [9/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [10/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [11/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [12/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [13/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [14/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [15/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [16/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [17/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [18/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [19/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [20/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [21/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [22/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [23/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [24/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [25/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [26/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [27/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [28/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [29/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [30/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [31/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [32/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [33/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [34/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [35/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [36/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#
# Best parameters:
# {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#
# OUTER RESULT: ROC=0.7084, PR=0.3674, Brier=0.1330
#
# ============================================================
# OUTER [5/5] Held-out project: pde
# ============================================================
# Selecting hyperparameters...
#     [1/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [2/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [3/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [4/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [5/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [6/36] {'class_weight': 'balanced', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [7/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [8/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [9/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [10/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [11/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [12/36] {'class_weight': 'balanced', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [13/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [14/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [15/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [16/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [17/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [18/36] {'class_weight': 'balanced', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [19/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [20/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [21/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [22/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [23/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [24/36] {'class_weight': 'balanced_subsample', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [25/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [26/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [27/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [28/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [29/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [30/36] {'class_weight': 'balanced_subsample', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#     [31/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 200}
#     [32/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 200}
#     [33/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#     [34/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 1, 'n_estimators': 200}
#     [35/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 3, 'n_estimators': 200}
#     [36/36] {'class_weight': 'balanced_subsample', 'max_depth': 20, 'max_features': 0.5, 'min_samples_leaf': 5, 'n_estimators': 200}
#
# Best parameters:
# {'class_weight': 'balanced', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}
#
# OUTER RESULT: ROC=0.7197, PR=0.3027, Brier=0.1758

# %%
nested_results[
    [
        "test_project",
        "roc_auc",
        "pr_auc",
        "brier",
        "best_max_depth",
        "best_min_samples_leaf",
        "best_max_features",
        "best_class_weight",
    ]
]
# Out:
#   test_project   roc_auc    pr_auc     brier  best_max_depth  \
# 0      eclipse  0.745615  0.525041  0.272843            10.0
# 1      equinox  0.748559  0.694341  0.196754            20.0
# 2       lucene  0.729117  0.337315  0.115551            10.0
# 3        mylyn  0.708398  0.367381  0.132994            10.0
# 4          pde  0.719672  0.302663  0.175824             NaN
#
#    best_min_samples_leaf best_max_features   best_class_weight
# 0                      5              sqrt            balanced
# 1                      5              sqrt            balanced
# 2                      5              sqrt  balanced_subsample
# 3                      5              sqrt            balanced
# 4                      5              sqrt            balanced

# %%
nested_results[
    ["roc_auc", "pr_auc", "brier"]
].agg(["mean", "std"])
# Out:
#        roc_auc    pr_auc     brier
# mean  0.730272  0.445348  0.178793
# std   0.017044  0.163139  0.061794

# %%
comparison = pd.DataFrame({
    "Untuned RF": {
        "roc_auc": 0.722437,
        "pr_auc": 0.421754,
        "brier": 0.157174,
    },
    "Nested-tuned RF": nested_results[
        ["roc_auc", "pr_auc", "brier"]
    ].mean(),
})

comparison
# Out:
#          Untuned RF  Nested-tuned RF
# roc_auc    0.722437         0.730272
# pr_auc     0.421754         0.445348
# brier      0.157174         0.178793

# %%
logistic_nested_results, logistic_tuning_results = (
    nested_logistic_lopo(all_df)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 logistic_nested_results, logistic_tuning_results = (
# ----> 2     nested_logistic_lopo(all_df)
#       3 )
#
# NameError: name 'nested_logistic_lopo' is not defined

# %%
logistic_nested_results, logistic_tuning_results = (
    nested_logistic_lopo(all_df)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 logistic_nested_results, logistic_tuning_results = (
# ----> 2     nested_logistic_lopo(all_df)
#       3 )
#
# NameError: name 'nested_logistic_lopo' is not defined

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import ParameterGrid

LOGISTIC_PARAM_GRID = {
    "C": [0.01, 0.1, 1.0, 10.0, 100.0],
    "class_weight": [None, "balanced"],
}

LOGISTIC_FEATURE_SETS = {
    "Change": CHANGE_FEATURES,
    "CK + Change": CK_FEATURES + CHANGE_FEATURES,
}

# %%
def make_logistic_model(params):
    return Pipeline([
        ("scaler", StandardScaler()),
        ("classifier", LogisticRegression(
            **params,
            max_iter=2000,
            random_state=42,
        )),
    ])

# %%
def evaluate_logistic_inner_lopo(
    training_df,
    features,
    params,
):
    scores = []

    for validation_project in sorted(
        training_df["project"].unique()
    ):
        inner_train = training_df[
            training_df["project"] != validation_project
        ]

        inner_validation = training_df[
            training_df["project"] == validation_project
        ]

        model = make_logistic_model(params)

        model.fit(
            inner_train[features],
            inner_train["defective"],
        )

        probabilities = model.predict_proba(
            inner_validation[features]
        )[:, 1]

        scores.append(
            average_precision_score(
                inner_validation["defective"],
                probabilities,
            )
        )

    return np.mean(scores)

# %%
def select_best_logistic_configuration(training_df):
    parameter_combinations = list(
        ParameterGrid(LOGISTIC_PARAM_GRID)
    )

    results = []

    best_score = -np.inf
    best_params = None
    best_feature_set_name = None
    best_features = None

    total = (
        len(LOGISTIC_FEATURE_SETS)
        * len(parameter_combinations)
    )

    current = 0

    for feature_set_name, features in LOGISTIC_FEATURE_SETS.items():
        for params in parameter_combinations:
            current += 1

            print(
                f"    [{current}/{total}] "
                f"{feature_set_name} | {params}",
                flush=True,
            )

            score = evaluate_logistic_inner_lopo(
                training_df,
                features,
                params,
            )

            results.append({
                "feature_set": feature_set_name,
                **params,
                "mean_pr_auc": score,
            })

            if score > best_score:
                best_score = score
                best_params = params.copy()
                best_feature_set_name = feature_set_name
                best_features = features.copy()

    return (
        best_feature_set_name,
        best_features,
        best_params,
        pd.DataFrame(results),
    )

# %%
def nested_logistic_lopo(df):
    outer_results = []
    tuning_results = {}

    outer_projects = sorted(
        df["project"].unique()
    )

    for i, test_project in enumerate(
        outer_projects,
        start=1,
    ):
        print()
        print("=" * 60)
        print(
            f"OUTER [{i}/{len(outer_projects)}] "
            f"Held-out project: {test_project}"
        )
        print("=" * 60)

        outer_train = df[
            df["project"] != test_project
        ]

        outer_test = df[
            df["project"] == test_project
        ]

        (
            feature_set_name,
            features,
            best_params,
            search_results,
        ) = select_best_logistic_configuration(
            outer_train
        )

        tuning_results[test_project] = search_results

        print()
        print("Best feature set:", feature_set_name)
        print("Best parameters:", best_params)

        model = make_logistic_model(
            best_params
        )

        model.fit(
            outer_train[features],
            outer_train["defective"],
        )

        probabilities = model.predict_proba(
            outer_test[features]
        )[:, 1]

        y_test = outer_test["defective"]

        result = {
            "test_project": test_project,
            "feature_set": feature_set_name,
            "C": best_params["C"],
            "class_weight": best_params["class_weight"],

            "roc_auc": roc_auc_score(
                y_test,
                probabilities,
            ),

            "pr_auc": average_precision_score(
                y_test,
                probabilities,
            ),

            "brier": brier_score_loss(
                y_test,
                probabilities,
            ),
        }

        outer_results.append(result)

        print(
            f"OUTER RESULT: "
            f"ROC={result['roc_auc']:.4f}, "
            f"PR={result['pr_auc']:.4f}, "
            f"Brier={result['brier']:.4f}"
        )

    return (
        pd.DataFrame(outer_results),
        tuning_results,
    )

# %%
logistic_nested_results, logistic_tuning_results = (
    nested_logistic_lopo(all_df)
)
# Out:
# ============================================================
# OUTER [1/5] Held-out project: eclipse
# ============================================================
#     [1/20] Change | {'C': 0.01, 'class_weight': None}
#     [2/20] Change | {'C': 0.01, 'class_weight': 'balanced'}
#     [3/20] Change | {'C': 0.1, 'class_weight': None}
#     [4/20] Change | {'C': 0.1, 'class_weight': 'balanced'}
#     [5/20] Change | {'C': 1.0, 'class_weight': None}
#     [6/20] Change | {'C': 1.0, 'class_weight': 'balanced'}
#     [7/20] Change | {'C': 10.0, 'class_weight': None}
#     [8/20] Change | {'C': 10.0, 'class_weight': 'balanced'}
#     [9/20] Change | {'C': 100.0, 'class_weight': None}
#     [10/20] Change | {'C': 100.0, 'class_weight': 'balanced'}
#     [11/20] CK + Change | {'C': 0.01, 'class_weight': None}
#     [12/20] CK + Change | {'C': 0.01, 'class_weight': 'balanced'}
#     [13/20] CK + Change | {'C': 0.1, 'class_weight': None}
#     [14/20] CK + Change | {'C': 0.1, 'class_weight': 'balanced'}
#     [15/20] CK + Change | {'C': 1.0, 'class_weight': None}
#     [16/20] CK + Change | {'C': 1.0, 'class_weight': 'balanced'}
#     [17/20] CK + Change | {'C': 10.0, 'class_weight': None}
#     [18/20] CK + Change | {'C': 10.0, 'class_weight': 'balanced'}
#     [19/20] CK + Change | {'C': 100.0, 'class_weight': None}
#     [20/20] CK + Change | {'C': 100.0, 'class_weight': 'balanced'}
#
# Best feature set: Change
# Best parameters: {'C': 0.01, 'class_weight': None}
# OUTER RESULT: ROC=0.7853, PR=0.5973, Brier=0.1414
#
# ============================================================
# OUTER [2/5] Held-out project: equinox
# ============================================================
#     [1/20] Change | {'C': 0.01, 'class_weight': None}
#     [2/20] Change | {'C': 0.01, 'class_weight': 'balanced'}
#     [3/20] Change | {'C': 0.1, 'class_weight': None}
#     [4/20] Change | {'C': 0.1, 'class_weight': 'balanced'}
#     [5/20] Change | {'C': 1.0, 'class_weight': None}
#     [6/20] Change | {'C': 1.0, 'class_weight': 'balanced'}
#     [7/20] Change | {'C': 10.0, 'class_weight': None}
#     [8/20] Change | {'C': 10.0, 'class_weight': 'balanced'}
#     [9/20] Change | {'C': 100.0, 'class_weight': None}
#     [10/20] Change | {'C': 100.0, 'class_weight': 'balanced'}
#     [11/20] CK + Change | {'C': 0.01, 'class_weight': None}
#     [12/20] CK + Change | {'C': 0.01, 'class_weight': 'balanced'}
#     [13/20] CK + Change | {'C': 0.1, 'class_weight': None}
#     [14/20] CK + Change | {'C': 0.1, 'class_weight': 'balanced'}
#     [15/20] CK + Change | {'C': 1.0, 'class_weight': None}
#     [16/20] CK + Change | {'C': 1.0, 'class_weight': 'balanced'}
#     [17/20] CK + Change | {'C': 10.0, 'class_weight': None}
#     [18/20] CK + Change | {'C': 10.0, 'class_weight': 'balanced'}
#     [19/20] CK + Change | {'C': 100.0, 'class_weight': None}
#     [20/20] CK + Change | {'C': 100.0, 'class_weight': 'balanced'}
#
# Best feature set: Change
# Best parameters: {'C': 0.01, 'class_weight': 'balanced'}
# OUTER RESULT: ROC=0.7439, PR=0.6982, Brier=0.2028
#
# ============================================================
# OUTER [3/5] Held-out project: lucene
# ============================================================
#     [1/20] Change | {'C': 0.01, 'class_weight': None}
#     [2/20] Change | {'C': 0.01, 'class_weight': 'balanced'}
#     [3/20] Change | {'C': 0.1, 'class_weight': None}
#     [4/20] Change | {'C': 0.1, 'class_weight': 'balanced'}
#     [5/20] Change | {'C': 1.0, 'class_weight': None}
#     [6/20] Change | {'C': 1.0, 'class_weight': 'balanced'}
#     [7/20] Change | {'C': 10.0, 'class_weight': None}
#     [8/20] Change | {'C': 10.0, 'class_weight': 'balanced'}
#     [9/20] Change | {'C': 100.0, 'class_weight': None}
#     [10/20] Change | {'C': 100.0, 'class_weight': 'balanced'}
#     [11/20] CK + Change | {'C': 0.01, 'class_weight': None}
#     [12/20] CK + Change | {'C': 0.01, 'class_weight': 'balanced'}
#     [13/20] CK + Change | {'C': 0.1, 'class_weight': None}
#     [14/20] CK + Change | {'C': 0.1, 'class_weight': 'balanced'}
#     [15/20] CK + Change | {'C': 1.0, 'class_weight': None}
#     [16/20] CK + Change | {'C': 1.0, 'class_weight': 'balanced'}
#     [17/20] CK + Change | {'C': 10.0, 'class_weight': None}
#     [18/20] CK + Change | {'C': 10.0, 'class_weight': 'balanced'}
#     [19/20] CK + Change | {'C': 100.0, 'class_weight': None}
#     [20/20] CK + Change | {'C': 100.0, 'class_weight': 'balanced'}
#
# Best feature set: CK + Change
# Best parameters: {'C': 0.01, 'class_weight': None}
# OUTER RESULT: ROC=0.7162, PR=0.3198, Brier=0.0775
#
# ============================================================
# OUTER [4/5] Held-out project: mylyn
# ============================================================
#     [1/20] Change | {'C': 0.01, 'class_weight': None}
#     [2/20] Change | {'C': 0.01, 'class_weight': 'balanced'}
#     [3/20] Change | {'C': 0.1, 'class_weight': None}
#     [4/20] Change | {'C': 0.1, 'class_weight': 'balanced'}
#     [5/20] Change | {'C': 1.0, 'class_weight': None}
#     [6/20] Change | {'C': 1.0, 'class_weight': 'balanced'}
#     [7/20] Change | {'C': 10.0, 'class_weight': None}
#     [8/20] Change | {'C': 10.0, 'class_weight': 'balanced'}
#     [9/20] Change | {'C': 100.0, 'class_weight': None}
#     [10/20] Change | {'C': 100.0, 'class_weight': 'balanced'}
#     [11/20] CK + Change | {'C': 0.01, 'class_weight': None}
#     [12/20] CK + Change | {'C': 0.01, 'class_weight': 'balanced'}
#     [13/20] CK + Change | {'C': 0.1, 'class_weight': None}
#     [14/20] CK + Change | {'C': 0.1, 'class_weight': 'balanced'}
#     [15/20] CK + Change | {'C': 1.0, 'class_weight': None}
#     [16/20] CK + Change | {'C': 1.0, 'class_weight': 'balanced'}
#     [17/20] CK + Change | {'C': 10.0, 'class_weight': None}
#     [18/20] CK + Change | {'C': 10.0, 'class_weight': 'balanced'}
#     [19/20] CK + Change | {'C': 100.0, 'class_weight': None}
#     [20/20] CK + Change | {'C': 100.0, 'class_weight': 'balanced'}
#
# Best feature set: Change
# Best parameters: {'C': 0.01, 'class_weight': None}
# OUTER RESULT: ROC=0.6534, PR=0.2771, Brier=0.1092
#
# ============================================================
# OUTER [5/5] Held-out project: pde
# ============================================================
#     [1/20] Change | {'C': 0.01, 'class_weight': None}
#     [2/20] Change | {'C': 0.01, 'class_weight': 'balanced'}
#     [3/20] Change | {'C': 0.1, 'class_weight': None}
#     [4/20] Change | {'C': 0.1, 'class_weight': 'balanced'}
#     [5/20] Change | {'C': 1.0, 'class_weight': None}
#     [6/20] Change | {'C': 1.0, 'class_weight': 'balanced'}
#     [7/20] Change | {'C': 10.0, 'class_weight': None}
#     [8/20] Change | {'C': 10.0, 'class_weight': 'balanced'}
#     [9/20] Change | {'C': 100.0, 'class_weight': None}
#     [10/20] Change | {'C': 100.0, 'class_weight': 'balanced'}
#     [11/20] CK + Change | {'C': 0.01, 'class_weight': None}
#     [12/20] CK + Change | {'C': 0.01, 'class_weight': 'balanced'}
#     [13/20] CK + Change | {'C': 0.1, 'class_weight': None}
#     [14/20] CK + Change | {'C': 0.1, 'class_weight': 'balanced'}
#     [15/20] CK + Change | {'C': 1.0, 'class_weight': None}
#     [16/20] CK + Change | {'C': 1.0, 'class_weight': 'balanced'}
#     [17/20] CK + Change | {'C': 10.0, 'class_weight': None}
#     [18/20] CK + Change | {'C': 10.0, 'class_weight': 'balanced'}
#     [19/20] CK + Change | {'C': 100.0, 'class_weight': None}
#     [20/20] CK + Change | {'C': 100.0, 'class_weight': 'balanced'}
#
# Best feature set: Change
# Best parameters: {'C': 0.01, 'class_weight': None}
# OUTER RESULT: ROC=0.7258, PR=0.3448, Brier=0.1096

# %%
logistic_nested_results[
    ["roc_auc", "pr_auc", "brier"]
].agg(["mean", "std"])
# Out:
#        roc_auc    pr_auc     brier
# mean  0.724939  0.447417  0.128131
# std   0.047938  0.187863  0.047480

# %%
model_comparison = pd.DataFrame({
    "Nested-tuned RF": nested_results[
        ["roc_auc", "pr_auc", "brier"]
    ].mean(),

    "Nested Logistic": logistic_nested_results[
        ["roc_auc", "pr_auc", "brier"]
    ].mean(),
})

model_comparison
# Out:
#          Nested-tuned RF  Nested Logistic
# roc_auc         0.730272         0.724939
# pr_auc          0.445348         0.447417
# brier           0.178793         0.128131

# %%
logistic_nested_results[
    [
        "test_project",
        "feature_set",
        "C",
        "class_weight",
        "roc_auc",
        "pr_auc",
        "brier",
    ]
]
# Out:
#   test_project  feature_set     C class_weight   roc_auc    pr_auc     brier
# 0      eclipse       Change  0.01          NaN  0.785291  0.597291  0.141422
# 1      equinox       Change  0.01     balanced  0.743948  0.698153  0.202843
# 2       lucene  CK + Change  0.01          NaN  0.716208  0.319815  0.077549
# 3        mylyn       Change  0.01          NaN  0.653444  0.277064  0.109200
# 4          pde       Change  0.01          NaN  0.725804  0.344764  0.109640

# %%
fold_comparison = (
    nested_results[
        ["test_project", "roc_auc", "pr_auc", "brier"]
    ]
    .merge(
        logistic_nested_results[
            ["test_project", "roc_auc", "pr_auc", "brier"]
        ],
        on="test_project",
        suffixes=("_rf", "_logistic"),
    )
)

fold_comparison["delta_roc"] = (
    fold_comparison["roc_auc_logistic"]
    - fold_comparison["roc_auc_rf"]
)

fold_comparison["delta_pr"] = (
    fold_comparison["pr_auc_logistic"]
    - fold_comparison["pr_auc_rf"]
)

fold_comparison["delta_brier"] = (
    fold_comparison["brier_logistic"]
    - fold_comparison["brier_rf"]
)

fold_comparison
# Out:
#   test_project  roc_auc_rf  pr_auc_rf  brier_rf  roc_auc_logistic  \
# 0      eclipse    0.745615   0.525041  0.272843          0.785291
# 1      equinox    0.748559   0.694341  0.196754          0.743948
# 2       lucene    0.729117   0.337315  0.115551          0.716208
# 3        mylyn    0.708398   0.367381  0.132994          0.653444
# 4          pde    0.719672   0.302663  0.175824          0.725804
#
#    pr_auc_logistic  brier_logistic  delta_roc  delta_pr  delta_brier
# 0         0.597291        0.141422   0.039676  0.072250    -0.131422
# 1         0.698153        0.202843  -0.004611  0.003812     0.006089
# 2         0.319815        0.077549  -0.012909 -0.017500    -0.038001
# 3         0.277064        0.109200  -0.054954 -0.090317    -0.023794
# 4         0.344764        0.109640   0.006131  0.042100    -0.066183

# %%
CK_CHANGE_FEATURES = CK_FEATURES + CHANGE_FEATURES

# %%
def nested_logistic_ck_change(df):
    outer_results = []
    tuning_results = {}

    parameter_combinations = list(
        ParameterGrid(LOGISTIC_PARAM_GRID)
    )

    outer_projects = sorted(df["project"].unique())

    for i, test_project in enumerate(outer_projects, start=1):
        print()
        print("=" * 60)
        print(
            f"OUTER [{i}/{len(outer_projects)}] "
            f"Held-out project: {test_project}"
        )
        print("=" * 60)

        outer_train = df[
            df["project"] != test_project
        ]

        outer_test = df[
            df["project"] == test_project
        ]

        best_score = -np.inf
        best_params = None
        search_results = []

        for j, params in enumerate(
            parameter_combinations,
            start=1,
        ):
            print(
                f"    [{j}/{len(parameter_combinations)}] "
                f"{params}",
                flush=True,
            )

            score = evaluate_logistic_inner_lopo(
                outer_train,
                CK_CHANGE_FEATURES,
                params,
            )

            search_results.append({
                **params,
                "mean_pr_auc": score,
            })

            if score > best_score:
                best_score = score
                best_params = params.copy()

        tuning_results[test_project] = pd.DataFrame(
            search_results
        )

        print("Best parameters:", best_params)

        model = make_logistic_model(best_params)

        model.fit(
            outer_train[CK_CHANGE_FEATURES],
            outer_train["defective"],
        )

        probabilities = model.predict_proba(
            outer_test[CK_CHANGE_FEATURES]
        )[:, 1]

        y_test = outer_test["defective"]

        result = {
            "test_project": test_project,
            "C": best_params["C"],
            "class_weight": best_params["class_weight"],
            "roc_auc": roc_auc_score(
                y_test, probabilities
            ),
            "pr_auc": average_precision_score(
                y_test, probabilities
            ),
            "brier": brier_score_loss(
                y_test, probabilities
            ),
        }

        outer_results.append(result)

        print(
            f"OUTER RESULT: "
            f"ROC={result['roc_auc']:.4f}, "
            f"PR={result['pr_auc']:.4f}, "
            f"Brier={result['brier']:.4f}"
        )

    return (
        pd.DataFrame(outer_results),
        tuning_results,
    )

# %%
logistic_ck_change_results, logistic_ck_change_tuning = (
    nested_logistic_ck_change(all_df)
)
# Out:
# ============================================================
# OUTER [1/5] Held-out project: eclipse
# ============================================================
#     [1/10] {'C': 0.01, 'class_weight': None}
#     [2/10] {'C': 0.01, 'class_weight': 'balanced'}
#     [3/10] {'C': 0.1, 'class_weight': None}
#     [4/10] {'C': 0.1, 'class_weight': 'balanced'}
#     [5/10] {'C': 1.0, 'class_weight': None}
#     [6/10] {'C': 1.0, 'class_weight': 'balanced'}
#     [7/10] {'C': 10.0, 'class_weight': None}
#     [8/10] {'C': 10.0, 'class_weight': 'balanced'}
#     [9/10] {'C': 100.0, 'class_weight': None}
#     [10/10] {'C': 100.0, 'class_weight': 'balanced'}
# Best parameters: {'C': 0.01, 'class_weight': 'balanced'}
# OUTER RESULT: ROC=0.7710, PR=0.5831, Brier=0.2566
#
# ============================================================
# OUTER [2/5] Held-out project: equinox
# ============================================================
#     [1/10] {'C': 0.01, 'class_weight': None}
#     [2/10] {'C': 0.01, 'class_weight': 'balanced'}
#     [3/10] {'C': 0.1, 'class_weight': None}
#     [4/10] {'C': 0.1, 'class_weight': 'balanced'}
#     [5/10] {'C': 1.0, 'class_weight': None}
#     [6/10] {'C': 1.0, 'class_weight': 'balanced'}
#     [7/10] {'C': 10.0, 'class_weight': None}
#     [8/10] {'C': 10.0, 'class_weight': 'balanced'}
#     [9/10] {'C': 100.0, 'class_weight': None}
#     [10/10] {'C': 100.0, 'class_weight': 'balanced'}
# Best parameters: {'C': 0.01, 'class_weight': 'balanced'}
# OUTER RESULT: ROC=0.7321, PR=0.6996, Brier=0.1994
#
# ============================================================
# OUTER [3/5] Held-out project: lucene
# ============================================================
#     [1/10] {'C': 0.01, 'class_weight': None}
#     [2/10] {'C': 0.01, 'class_weight': 'balanced'}
#     [3/10] {'C': 0.1, 'class_weight': None}
#     [4/10] {'C': 0.1, 'class_weight': 'balanced'}
#     [5/10] {'C': 1.0, 'class_weight': None}
#     [6/10] {'C': 1.0, 'class_weight': 'balanced'}
#     [7/10] {'C': 10.0, 'class_weight': None}
#     [8/10] {'C': 10.0, 'class_weight': 'balanced'}
#     [9/10] {'C': 100.0, 'class_weight': None}
#     [10/10] {'C': 100.0, 'class_weight': 'balanced'}
# Best parameters: {'C': 0.01, 'class_weight': None}
# OUTER RESULT: ROC=0.7162, PR=0.3198, Brier=0.0775
#
# ============================================================
# OUTER [4/5] Held-out project: mylyn
# ============================================================
#     [1/10] {'C': 0.01, 'class_weight': None}
#     [2/10] {'C': 0.01, 'class_weight': 'balanced'}
#     [3/10] {'C': 0.1, 'class_weight': None}
#     [4/10] {'C': 0.1, 'class_weight': 'balanced'}
#     [5/10] {'C': 1.0, 'class_weight': None}
#     [6/10] {'C': 1.0, 'class_weight': 'balanced'}
#     [7/10] {'C': 10.0, 'class_weight': None}
#     [8/10] {'C': 10.0, 'class_weight': 'balanced'}
#     [9/10] {'C': 100.0, 'class_weight': None}
#     [10/10] {'C': 100.0, 'class_weight': 'balanced'}
# Best parameters: {'C': 0.01, 'class_weight': None}
# OUTER RESULT: ROC=0.6913, PR=0.3050, Brier=0.1064
#
# ============================================================
# OUTER [5/5] Held-out project: pde
# ============================================================
#     [1/10] {'C': 0.01, 'class_weight': None}
#     [2/10] {'C': 0.01, 'class_weight': 'balanced'}
#     [3/10] {'C': 0.1, 'class_weight': None}
#     [4/10] {'C': 0.1, 'class_weight': 'balanced'}
#     [5/10] {'C': 1.0, 'class_weight': None}
#     [6/10] {'C': 1.0, 'class_weight': 'balanced'}
#     [7/10] {'C': 10.0, 'class_weight': None}
#     [8/10] {'C': 10.0, 'class_weight': 'balanced'}
#     [9/10] {'C': 100.0, 'class_weight': None}
#     [10/10] {'C': 100.0, 'class_weight': 'balanced'}
# Best parameters: {'C': 0.01, 'class_weight': None}
# OUTER RESULT: ROC=0.7521, PR=0.3509, Brier=0.1090

# %%
logistic_ck_change_results[
    ["roc_auc", "pr_auc", "brier"]
].agg(["mean", "std"])
# Out:
#        roc_auc    pr_auc     brier
# mean  0.732546  0.451698  0.149789
# std   0.030934  0.178770  0.075227

# %%
fair_model_comparison = pd.DataFrame({
    "Random Forest": nested_results[
        ["roc_auc", "pr_auc", "brier"]
    ].mean(),

    "Logistic Regression": logistic_ck_change_results[
        ["roc_auc", "pr_auc", "brier"]
    ].mean(),
})

fair_model_comparison
# Out:
#          Random Forest  Logistic Regression
# roc_auc       0.730272             0.732546
# pr_auc        0.445348             0.451698
# brier         0.178793             0.149789

# %%
from sklearn.calibration import CalibratedClassifierCV

# %%
from sklearn.base import clone
from sklearn.linear_model import LogisticRegression

# %%
def fit_project_aware_sigmoid_calibrator(
    model,
    training_df,
    features,
):
    calibration_scores = []
    calibration_targets = []

    projects = sorted(
        training_df["project"].unique()
    )

    for calibration_project in projects:
        calibration_train = training_df[
            training_df["project"] != calibration_project
        ]

        calibration_validation = training_df[
            training_df["project"] == calibration_project
        ]

        fold_model = clone(model)

        fold_model.fit(
            calibration_train[features],
            calibration_train["defective"],
        )

        fold_probabilities = fold_model.predict_proba(
            calibration_validation[features]
        )[:, 1]

        calibration_scores.extend(
            fold_probabilities
        )

        calibration_targets.extend(
            calibration_validation["defective"]
        )

    calibration_scores = np.array(
        calibration_scores
    ).reshape(-1, 1)

    calibration_targets = np.array(
        calibration_targets
    )

    calibrator = LogisticRegression(
        C=1e6,
        max_iter=2000,
    )

    calibrator.fit(
        calibration_scores,
        calibration_targets,
    )

    final_model = clone(model)

    final_model.fit(
        training_df[features],
        training_df["defective"],
    )

    return final_model, calibrator

# %%
def predict_calibrated_probability(
    model,
    calibrator,
    X,
):
    raw_probabilities = model.predict_proba(X)[:, 1]

    calibrated_probabilities = calibrator.predict_proba(
        raw_probabilities.reshape(-1, 1)
    )[:, 1]

    return raw_probabilities, calibrated_probabilities

# %%
def evaluate_logistic_calibration(df):
    results = []

    for test_project in sorted(
        df["project"].unique()
    ):
        print(f"Testing {test_project}...", flush=True)

        outer_train = df[
            df["project"] != test_project
        ]

        outer_test = df[
            df["project"] == test_project
        ]

        selected = logistic_ck_change_results[
            logistic_ck_change_results["test_project"]
            == test_project
        ].iloc[0]

        params = {
            "C": float(selected["C"]),
            "class_weight": selected["class_weight"],
        }

        # Pandas may represent None as NaN
        if pd.isna(params["class_weight"]):
            params["class_weight"] = None

        base_model = make_logistic_model(params)

        model, calibrator = (
            fit_project_aware_sigmoid_calibrator(
                base_model,
                outer_train,
                CK_CHANGE_FEATURES,
            )
        )

        raw_prob, calibrated_prob = (
            predict_calibrated_probability(
                model,
                calibrator,
                outer_test[CK_CHANGE_FEATURES],
            )
        )

        y_test = outer_test["defective"]

        results.append({
            "test_project": test_project,

            "raw_roc": roc_auc_score(
                y_test, raw_prob
            ),
            "cal_roc": roc_auc_score(
                y_test, calibrated_prob
            ),

            "raw_pr": average_precision_score(
                y_test, raw_prob
            ),
            "cal_pr": average_precision_score(
                y_test, calibrated_prob
            ),

            "raw_brier": brier_score_loss(
                y_test, raw_prob
            ),
            "cal_brier": brier_score_loss(
                y_test, calibrated_prob
            ),
        })

    return pd.DataFrame(results)

# %%
logistic_calibration_results = (
    evaluate_logistic_calibration(all_df)
)

logistic_calibration_results
# Out:
# Testing eclipse...
# Testing equinox...
# Testing lucene...
# Testing mylyn...
# Testing pde...
#   test_project   raw_roc   cal_roc    raw_pr    cal_pr  raw_brier  cal_brier
# 0      eclipse  0.771041  0.771041  0.583139  0.583139   0.256587   0.130026
# 1      equinox  0.732061  0.732061  0.699649  0.699649   0.199429   0.272937
# 2       lucene  0.716208  0.716208  0.319815  0.319815   0.077549   0.079023
# 3        mylyn  0.691347  0.691347  0.304967  0.304967   0.106415   0.108580
# 4          pde  0.752073  0.752073  0.350921  0.350921   0.108966   0.111193

# %%
logistic_calibration_results[
    [
        "raw_roc",
        "cal_roc",
        "raw_pr",
        "cal_pr",
        "raw_brier",
        "cal_brier",
    ]
].mean()
# Out:
# raw_roc      0.732546
# cal_roc      0.732546
# raw_pr       0.451698
# cal_pr       0.451698
# raw_brier    0.149789
# cal_brier    0.140352
# dtype: float64

# %%
nested_results.columns
# Out:
# Index(['test_project', 'n_train', 'n_test', 'defect_rate', 'roc_auc', 'pr_auc',
#        'brier', 'best_class_weight', 'best_max_depth', 'best_max_features',
#        'best_min_samples_leaf', 'best_n_estimators'],
#       dtype='str')

# %%
nested_results
# Out:
#   test_project  n_train  n_test  defect_rate   roc_auc    pr_auc     brier  \
# 0      eclipse     4374     997     0.206620  0.745615  0.525041  0.272843
# 1      equinox     5047     324     0.398148  0.748559  0.694341  0.196754
# 2       lucene     4680     691     0.092619  0.729117  0.337315  0.115551
# 3        mylyn     3509    1862     0.131579  0.708398  0.367381  0.132994
# 4          pde     3874    1497     0.139613  0.719672  0.302663  0.175824
#
#     best_class_weight  best_max_depth best_max_features  \
# 0            balanced            10.0              sqrt
# 1            balanced            20.0              sqrt
# 2  balanced_subsample            10.0              sqrt
# 3            balanced            10.0              sqrt
# 4            balanced             NaN              sqrt
#
#    best_min_samples_leaf  best_n_estimators
# 0                      5                200
# 1                      5                200
# 2                      5                200
# 3                      5                200
# 4                      5                200
